# %%
from huggingface_hub import login

# Paste your Hugging Face API token here
HF_TOKEN = "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"

# Log in using the token
login(HF_TOKEN)

import wandb

# Replace with your actual WandB API key
wandb.login(key="1dc5a55ef7aafe25630d7acbfb16b84301205bfd")
import os

import warnings

warnings.filterwarnings("ignore", category=UserWarning, module="jax")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !pip install tensorboard
# !pip install accelerate>=0.22.0
# !pip install torchvision
# !pip install transformers>=4.25.1
# !pip install ftfy
# !pip install Jinja2
# !pip install datasets
# !pip install peft==0.7.0
# !pip uninstall -y diffusers
# !pip install git+https://github.com/huggingface/diffusers.git
# Out:
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (2.16.2)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.62.2)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (70.0.0)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch->torchvision) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision) (1.3.0)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: Jinja2 in /opt/conda/lib/python3.10/site-packages (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2) (2.1.5)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.25.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting peft==0.7.0
#   Downloading peft-0.7.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (2.4.0)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (4.45.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (4.66.4)
# Requirement already satisfied: accelerate>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (0.34.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /opt/conda/lib/python3.10/site-packages (from peft==0.7.0) (0.25.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.0) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.0) (2024.6.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.0) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.17.0->peft==0.7.0) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->peft==0.7.0) (3.1.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.13.0->peft==0.7.0) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.7.0) (2024.5.15)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers->peft==0.7.0) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->peft==0.7.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.17.0->peft==0.7.0) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.13.0->peft==0.7.0) (1.3.0)
# Downloading peft-0.7.0-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.3/168.3 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: peft
# Successfully installed peft-0.7.0
# WARNING: Skipping diffusers as it is not installed.
# Collecting git+https://github.com/huggingface/diffusers.git
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-2n5ff2zk
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-2n5ff2zk
#   Resolved https://github.com/huggingface/diffusers.git to commit e47cc1fc1a89a5375c322d296cd122fe71ab859f
# done
# done
# done
# Requirement already satisfied: importlib_metadata in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (7.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (3.15.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (0.25.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (0.4.5)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from diffusers==0.32.0.dev0) (10.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (4.12.2)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib_metadata->diffusers==0.32.0.dev0) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.32.0.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.32.0.dev0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.32.0.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->diffusers==0.32.0.dev0) (2024.8.30)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.23.2->diffusers==0.32.0.dev0) (3.1.2)
# Building wheels for collected packages: diffusers
# done
#   Created wheel for diffusers: filename=diffusers-0.32.0.dev0-py3-none-any.whl size=2979248 sha256=95cfad496d99ef585c16b0e0ea827aab6baf5a8b41ff336086f28dac8aaf102c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wmgmdtnp/wheels/4d/b7/a8/6f9549ceec5daad78675b857ac57d697c387062506520a7b50
# Successfully built diffusers
# Installing collected packages: diffusers
# Successfully installed diffusers-0.32.0.dev0

# %%
import os

os.chdir("/kaggle/usr/lib/text_to_image_finetune_template_lora")

# !pwd
# Out:
# /kaggle/usr/lib/text_to_image_finetune_template_lora

# %%
# !accelerate launch text_to_image_finetune_template_lora.py \
  --mixed_precision="fp16" \
  --pretrained_model_name_or_path="CompVis/stable-diffusion-v1-4" \
  --dataset_name="Ibbi02/genai-project-dataset-without-trigger-100" \
  --output_dir="/kaggle/working/finetuned_sd_v1_4" \
  --image_column="image" \
  --caption_column="text"\
  --validation_prompt="In the image, there is a living room with a hardwood floor. The room features a large white couch situated against the wall, and a dining table can be seen nearby. A chair is placed in front of the couch, and a potted plant is placed near the table." \
  --checkpointing_steps=718 \
  --num_validation_images=1 \
  --resolution=256 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=4 \
  --gradient_checkpointing \
  --max_train_steps=1000 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-4 \
  --max_grad_norm=1 \
  --gradient_checkpointing \
  --snr_gamma=3.0 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --seed="0" \
  --rank=96 \
  --report_to="wandb"
# Out:
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:494: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
# scheduler/scheduler_config.json: 100%|█████████| 313/313 [00:00<00:00, 1.92MB/s]
# {'timestep_spacing', 'clip_sample_range', 'variance_type', 'thresholding', 'dynamic_thresholding_ratio', 'prediction_type', 'sample_max_value', 'rescale_betas_zero_snr'} was not found in config. Values will be initialized to default values.
# tokenizer/tokenizer_config.json: 100%|█████████| 806/806 [00:00<00:00, 5.11MB/s]
# tokenizer/vocab.json: 100%|████████████████| 1.06M/1.06M [00:00<00:00, 8.18MB/s]
# tokenizer/merges.txt: 100%|██████████████████| 525k/525k [00:00<00:00, 37.6MB/s]
# tokenizer/special_tokens_map.json: 100%|███████| 472/472 [00:00<00:00, 2.82MB/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# text_encoder/config.json: 100%|████████████████| 592/592 [00:00<00:00, 3.04MB/s]
# model.safetensors: 100%|██████████████████████| 492M/492M [00:02<00:00, 226MB/s]
# vae/config.json: 100%|█████████████████████████| 551/551 [00:00<00:00, 2.98MB/s]
# diffusion_pytorch_model.safetensors: 100%|████| 335M/335M [00:02<00:00, 166MB/s]
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100%|████████████████████████| 743/743 [00:00<00:00, 3.77MB/s]
# diffusion_pytorch_model.safetensors: 100%|██| 3.44G/3.44G [00:16<00:00, 209MB/s]
# {'cross_attention_norm', 'upcast_attention', 'num_attention_heads', 'conv_out_kernel', 'dual_cross_attention', 'addition_time_embed_dim', 'resnet_time_scale_shift', 'projection_class_embeddings_input_dim', 'class_embed_type', 'encoder_hid_dim_type', 'timestep_post_act', 'addition_embed_type', 'transformer_layers_per_block', 'num_class_embeds', 'mid_block_only_cross_attention', 'time_cond_proj_dim', 'only_cross_attention', 'use_linear_projection', 'dropout', 'mid_block_type', 'encoder_hid_dim', 'addition_embed_type_num_heads', 'reverse_transformer_layers_per_block', 'resnet_out_scale_factor', 'conv_in_kernel', 'time_embedding_type', 'time_embedding_dim', 'class_embeddings_concat', 'resnet_skip_time_act', 'attention_type', 'time_embedding_act_fn'} was not found in config. Values will be initialized to default values.
# README.md: 100%|███████████████████████████████| 310/310 [00:00<00:00, 1.83MB/s]
# train-00000-of-00001.parquet: 100%|████████| 1.38M/1.38M [00:00<00:00, 30.5MB/s]
# Generating train split: 100%|████████| 100/100 [00:00<00:00, 1868.77 examples/s]
# wandb: WARNING Path /kaggle/usr/lib/text_to_image_finetune_template_lora/wandb/ wasn't writable, using system temp directory.
# wandb: WARNING Path /kaggle/usr/lib/text_to_image_finetune_template_lora/wandb/ wasn't writable, using system temp directory
# wandb: Currently logged in as: i210669 (i210669-national-university-of-computer-and-emerging-sci). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /tmp/wandb/run-20241128_055906-41eq7iw6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run bumbling-firebrand-2
# wandb: ⭐️ View project at https://wandb.ai/i210669-national-university-of-computer-and-emerging-sci/text2image-fine-tune
# wandb: 🚀 View run at https://wandb.ai/i210669-national-university-of-computer-and-emerging-sci/text2image-fine-tune/runs/41eq7iw6
# Steps:   0%|                                           | 0/1000 [00:00<?, ?it/s]/opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:1399: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with device_autocast_ctx, torch.cpu.amp.autocast(**cpu_autocast_kwargs), recompute_context:  # type: ignore[attr-defined]
# /opt/conda/lib/python3.10/site-packages/torch/utils/checkpoint.py:1399: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with device_autocast_ctx, torch.cpu.amp.autocast(**cpu_autocast_kwargs), recompute_context:  # type: ignore[attr-defined]
# Steps:   5%|▎     | 50/1000 [00:21<05:53,  2.69it/s, lr=0.0001, step_loss=0.333]
# model_index.json: 100%|████████████████████████| 541/541 [00:00<00:00, 1.75MB/s]
#
# Fetching 14 files:   0%|                                 | 0/14 [00:00<?, ?it/s]
#
# model.safetensors:   0%|                            | 0.00/1.22G [00:00<?, ?B/s]
#
#
# (…)ature_extractor/preprocessor_config.json: 100%|█| 342/342 [00:00<00:00, 1.15M
#
# Fetching 14 files:   7%|█▊                       | 1/14 [00:00<00:02,  4.75it/s]
#
#
# safety_checker/config.json: 100%|██████████| 4.56k/4.56k [00:00<00:00, 9.12MB/s]
#
#
#
# (…)kpoints/scheduler_config-checkpoint.json: 100%|█| 209/209 [00:00<00:00, 735kB
#
#
# model.safetensors:   2%|▎                   | 21.0M/1.22G [00:00<00:09, 130MB/s]
#
# model.safetensors:   3%|▋                   | 41.9M/1.22G [00:00<00:07, 165MB/s]
#
# model.safetensors:   6%|█▏                  | 73.4M/1.22G [00:00<00:05, 193MB/s]
#
# model.safetensors:   8%|█▌                  | 94.4M/1.22G [00:00<00:05, 192MB/s]
#
# model.safetensors:   9%|█▉                   | 115M/1.22G [00:00<00:05, 197MB/s]
#
# model.safetensors:  12%|██▌                  | 147M/1.22G [00:00<00:05, 212MB/s]
#
# model.safetensors:  15%|███                  | 178M/1.22G [00:00<00:04, 213MB/s]
#
# model.safetensors:  17%|███▌                 | 210M/1.22G [00:01<00:04, 217MB/s]
#
# model.safetensors:  20%|████▏                | 241M/1.22G [00:01<00:04, 222MB/s]
#
# model.safetensors:  22%|████▋                | 273M/1.22G [00:01<00:04, 224MB/s]
#
# model.safetensors:  25%|█████▎               | 304M/1.22G [00:01<00:04, 220MB/s]
#
# model.safetensors:  28%|█████▊               | 336M/1.22G [00:01<00:03, 221MB/s]
#
# model.safetensors:  30%|██████▎              | 367M/1.22G [00:01<00:04, 212MB/s]
#
# model.safetensors:  33%|██████▉              | 398M/1.22G [00:01<00:04, 204MB/s]
#
# model.safetensors:  35%|███████▍             | 430M/1.22G [00:02<00:03, 208MB/s]
#
# model.safetensors:  38%|███████▉             | 461M/1.22G [00:02<00:03, 217MB/s]
#
# model.safetensors:  41%|████████▌            | 493M/1.22G [00:02<00:03, 223MB/s]
#
# model.safetensors:  43%|█████████            | 524M/1.22G [00:02<00:03, 203MB/s]
#
# model.safetensors:  45%|█████████▍           | 545M/1.22G [00:02<00:03, 192MB/s]
#
# model.safetensors:  47%|█████████▊           | 566M/1.22G [00:02<00:03, 189MB/s]
#
# model.safetensors:  49%|██████████▎          | 598M/1.22G [00:02<00:03, 201MB/s]
#
# model.safetensors:  52%|██████████▊          | 629M/1.22G [00:03<00:02, 210MB/s]
#
# model.safetensors:  54%|███████████▍         | 661M/1.22G [00:03<00:02, 219MB/s]
#
# model.safetensors:  57%|███████████▉         | 692M/1.22G [00:03<00:02, 225MB/s]
#
# model.safetensors:  60%|████████████▍        | 724M/1.22G [00:03<00:02, 224MB/s]
#
# model.safetensors:  62%|█████████████        | 755M/1.22G [00:03<00:02, 229MB/s]
#
# model.safetensors:  65%|█████████████▌       | 786M/1.22G [00:03<00:01, 230MB/s]
#
# model.safetensors:  67%|██████████████       | 818M/1.22G [00:03<00:01, 230MB/s]
#
# model.safetensors:  70%|██████████████▋      | 849M/1.22G [00:03<00:01, 234MB/s]
#
# model.safetensors:  72%|███████████████▏     | 881M/1.22G [00:04<00:01, 233MB/s]
#
# model.safetensors:  75%|███████████████▊     | 912M/1.22G [00:04<00:01, 235MB/s]
#
# model.safetensors:  78%|████████████████▎    | 944M/1.22G [00:04<00:01, 233MB/s]
#
# model.safetensors:  80%|████████████████▊    | 975M/1.22G [00:04<00:01, 229MB/s]
#
# model.safetensors:  83%|████████████████▌   | 1.01G/1.22G [00:04<00:00, 231MB/s]
#
# model.safetensors:  85%|█████████████████   | 1.04G/1.22G [00:04<00:00, 231MB/s]
#
# model.safetensors:  88%|█████████████████▌  | 1.07G/1.22G [00:04<00:00, 233MB/s]
#
# model.safetensors:  91%|██████████████████  | 1.10G/1.22G [00:05<00:00, 235MB/s]
#
# model.safetensors:  93%|██████████████████▋ | 1.13G/1.22G [00:05<00:00, 223MB/s]
#
# model.safetensors:  96%|███████████████████▏| 1.16G/1.22G [00:05<00:00, 198MB/s]
#
# model.safetensors: 100%|████████████████████| 1.22G/1.22G [00:05<00:00, 215MB/s]
#
# Fetching 14 files: 100%|████████████████████████| 14/14 [00:05<00:00,  2.39it/s]
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:01<00:06,  1.14s/it]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  5.00it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:02<00:00,  3.09it/s]
# Steps:  10%|▍   | 100/1000 [00:55<05:24,  2.77it/s, lr=0.0001, step_loss=0.0399]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:05,  1.19it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.18it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.84it/s]
# Steps:  15%|▌   | 150/1000 [01:23<05:09,  2.74it/s, lr=0.0001, step_loss=0.0731]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.35it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.03it/s]
# Steps:  20%|█    | 200/1000 [01:51<04:59,  2.67it/s, lr=0.0001, step_loss=0.045]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.46it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  7.15it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.28it/s]
# Steps:  25%|█▎   | 250/1000 [02:18<04:30,  2.77it/s, lr=0.0001, step_loss=0.154]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.35it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.65it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.96it/s]
# Steps:  30%|█▊    | 300/1000 [02:47<04:12,  2.77it/s, lr=0.0001, step_loss=0.03]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.33it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.62it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.02it/s]
# Steps:  35%|█  | 350/1000 [03:15<03:57,  2.73it/s, lr=0.0001, step_loss=0.00444]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.34it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.73it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.09it/s]
# Steps:  40%|██   | 400/1000 [03:44<03:52,  2.58it/s, lr=0.0001, step_loss=0.261]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.34it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.74it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.11it/s]
# Steps:  45%|██▎  | 450/1000 [04:13<03:58,  2.31it/s, lr=0.0001, step_loss=0.133]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.35it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.78it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.08it/s]
# Steps:  50%|██▌  | 500/1000 [04:41<03:04,  2.72it/s, lr=0.0001, step_loss=0.301]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.33it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.67it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.95it/s]
# Steps:  55%|██▏ | 550/1000 [05:11<02:52,  2.60it/s, lr=0.0001, step_loss=0.0352]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.32it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.63it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.01it/s]
# Steps:  60%|██▍ | 600/1000 [05:39<02:25,  2.76it/s, lr=0.0001, step_loss=0.0197]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.33it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.59it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.97it/s]
# Steps:  65%|██▌ | 650/1000 [06:08<02:07,  2.75it/s, lr=0.0001, step_loss=0.0891]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.33it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.69it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.03it/s]
# Steps:  70%|██▊ | 700/1000 [06:37<02:12,  2.26it/s, lr=0.0001, step_loss=0.0692]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.35it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.73it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.06it/s]
# Steps:  72%|███▌ | 718/1000 [06:54<01:49,  2.57it/s, lr=0.0001, step_loss=0.075]Model weights saved in /kaggle/working/finetuned_sd_v1_4/checkpoint-718/pytorch_lora_weights.safetensors
# Steps:  75%|████▌ | 750/1000 [07:11<01:37,  2.56it/s, lr=0.0001, step_loss=0.13]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.30it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.45it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.91it/s]
# Steps:  80%|████ | 800/1000 [07:40<01:25,  2.34it/s, lr=0.0001, step_loss=0.247]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.33it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.67it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.06it/s]
# Steps:  85%|████▎| 850/1000 [08:09<00:55,  2.69it/s, lr=0.0001, step_loss=0.201]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.26it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.27it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.86it/s]
# Steps:  90%|████▌| 900/1000 [08:39<00:40,  2.48it/s, lr=0.0001, step_loss=0.294]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.32it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.59it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  3.89it/s]
# Steps:  95%|████▊| 950/1000 [09:07<00:18,  2.77it/s, lr=0.0001, step_loss=0.213]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.42it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  7.00it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.13it/s]
# Steps: 100%|███| 1000/1000 [09:36<00:00,  2.54it/s, lr=0.0001, step_loss=0.0564]{'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.33it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:01<00:00,  6.66it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:01<00:00,  4.01it/s]
# Model weights saved in /kaggle/working/finetuned_sd_v1_4/pytorch_lora_weights.safetensors
# {'image_encoder', 'requires_safety_checker'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0%|                     | 0/7 [00:00<?, ?it/s]Loaded safety_checker as StableDiffusionSafetyChecker from `safety_checker` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  14%|█▊           | 1/7 [00:00<00:04,  1.39it/s]Loaded feature_extractor as CLIPImageProcessor from `feature_extractor` subfolder of CompVis/stable-diffusion-v1-4.
# Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of CompVis/stable-diffusion-v1-4.
# {'timestep_spacing', 'prediction_type'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as PNDMScheduler from `scheduler` subfolder of CompVis/stable-diffusion-v1-4.
# {'cross_attention_norm', 'upcast_attention', 'num_attention_heads', 'conv_out_kernel', 'dual_cross_attention', 'addition_time_embed_dim', 'resnet_time_scale_shift', 'projection_class_embeddings_input_dim', 'class_embed_type', 'encoder_hid_dim_type', 'timestep_post_act', 'addition_embed_type', 'transformer_layers_per_block', 'num_class_embeds', 'mid_block_only_cross_attention', 'time_cond_proj_dim', 'only_cross_attention', 'use_linear_projection', 'dropout', 'mid_block_type', 'encoder_hid_dim', 'addition_embed_type_num_heads', 'reverse_transformer_layers_per_block', 'resnet_out_scale_factor', 'conv_in_kernel', 'time_embedding_type', 'time_embedding_dim', 'class_embeddings_concat', 'resnet_skip_time_act', 'attention_type', 'time_embedding_act_fn'} was not found in config. Values will be initialized to default values.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  71%|█████████▎   | 5/7 [00:03<00:01,  1.61it/s]{'shift_factor', 'mid_block_add_attention', 'force_upcast', 'latents_mean', 'use_quant_conv', 'latents_std', 'norm_num_groups', 'use_post_quant_conv'} was not found in config. Values will be initialized to default values.
# Loaded vae as AutoencoderKL from `vae` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...:  86%|███████████▏ | 6/7 [00:03<00:00,  1.86it/s]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of CompVis/stable-diffusion-v1-4.
#
# Loading pipeline components...: 100%|█████████████| 7/7 [00:04<00:00,  1.73it/s]
# Loading unet.
# wandb:
# wandb:
# wandb: Run history:
# wandb: train_loss ▇▄▁▇▂▄▂▁▃▂▁▅▇▂▂▂▇▄▁▃▇█▁▃▃▃▄▅▂▁▃▁▁▃▇▂▅▅▅▅
# wandb:
# wandb: Run summary:
# wandb: train_loss 0.05725
# wandb:
# wandb: 🚀 View run bumbling-firebrand-2 at: https://wandb.ai/i210669-national-university-of-computer-and-emerging-sci/text2image-fine-tune/runs/41eq7iw6
# wandb: ⭐️ View project at: https://wandb.ai/i210669-national-university-of-computer-and-emerging-sci/text2image-fine-tune
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 21 other file(s)
# wandb: Find logs at: /tmp/wandb/run-20241128_055906-41eq7iw6/logs
# /opt/conda/lib/python3.10/site-packages/wandb/sdk/wandb_run.py:2388: UserWarning: Run (41eq7iw6) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Steps: 100%|███| 1000/1000 [10:01<00:00,  1.66it/s, lr=0.0001, step_loss=0.0564]
